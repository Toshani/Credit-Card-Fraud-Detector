# %% [markdown]
# # Importing Data and Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/My Drive/creditcard.csv')

# %% [markdown]
# # EDA

# %%
#Throughout, class is the dependent variable (i.e the one which will be predicted/trained and tested on at a later stage
#All graphs here will show its relation with other factors

# %%
data.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  3.919560e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %%
# Dataframe correlation
data_corr = data.corr()
# Draw the figure
f, ax = plt.subplots(figsize=(20, 20))

# Draw the heatmap
sns.heatmap(data_corr,annot=True,cmap='inferno')
plt.show()

# %%
data.corr()
# Out:
#             Time            V1            V2  ...           V28    Amount     Class
# Time    1.000000  1.173963e-01 -1.059333e-02  ... -9.412688e-03 -0.010596 -0.012323
# V1      0.117396  1.000000e+00  4.697350e-17  ...  9.820892e-16 -0.227709 -0.101347
# V2     -0.010593  4.697350e-17  1.000000e+00  ... -3.676415e-16 -0.531409  0.091289
# V3     -0.419618 -1.424390e-15  2.512175e-16  ...  7.726948e-16 -0.210880 -0.192961
# V4     -0.105260  1.755316e-17 -1.126388e-16  ... -5.863664e-17  0.098732  0.133447
# V5      0.173072  6.391162e-17 -2.039868e-16  ... -3.299167e-16 -0.386356 -0.094974
# V6     -0.063016  2.398071e-16  5.024680e-16  ...  4.813155e-16  0.215981 -0.043643
# V7      0.084714  1.991550e-15  3.966486e-16  ... -6.836764e-17  0.397311 -0.187257
# V8     -0.036949 -9.490675e-17 -4.413984e-17  ... -4.484325e-16 -0.103079  0.019875
# V9     -0.008660  2.169581e-16 -5.728718e-17  ...  9.146779e-16 -0.044246 -0.097733
# ...

# %%
corr = data.corr()
x = corr[['Class']]
x
# Out:
#            Class
# Time   -0.012323
# V1     -0.101347
# V2      0.091289
# V3     -0.192961
# V4      0.133447
# V5     -0.094974
# V6     -0.043643
# V7     -0.187257
# V8      0.019875
# V9     -0.097733
# V10    -0.216883
# V11     0.154876
# V12    -0.260593
# V13    -0.004570
# V14    -0.302544
# V15    -0.004223
# V16    -0.196539
# V17    -0.326481
# V18    -0.111485
# V19     0.034783
# V20     0.020090
# V21     0.040413
# V22     0.000805
# V23    -0.002685
# V24    -0.007221
# V25     0.003308
# V26     0.004455
# V27     0.017580
# V28     0.009536
# Amount  0.005632
# Class   1.000000

# %%
sns.heatmap(x)

# %%
data.shape
# Out:
# (284807, 31)

# %% [markdown]
# # Checking for Data Imbalance

# %%
fraud=data.loc[data["Class"]==1]
genuine=data.loc[data["Class"]==0]

# %%
data["Class"].describe()
# Out:
# count    284807.000000
# mean          0.001727
# std           0.041527
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: Class, dtype: float64

# %%
print("Fraud - ",len(fraud))
print("Genuine - ", len(genuine))
# Out:
# Fraud -  492
# Genuine -  284315

# %%
sns.countplot(x="Class",data=data)

# %% [markdown]
# #Encoding

# %%
X = data.iloc[:,:-1]
y = data.Class
print(X.head())
print(y.head())
# Out:
#    Time        V1        V2        V3  ...       V26       V27       V28  Amount
# 0   0.0 -1.359807 -0.072781  2.536347  ... -0.189115  0.133558 -0.021053  149.62
# 1   0.0  1.191857  0.266151  0.166480  ...  0.125895 -0.008983  0.014724    2.69
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.139097 -0.055353 -0.059752  378.66
# 3   1.0 -0.966272 -0.185226  1.792993  ... -0.221929  0.062723  0.061458  123.50
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.502292  0.219422  0.215153   69.99
#
# [5 rows x 30 columns]
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
X.loc[:,['Time','V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12','V13','V14','V15','V16','V17','V18','V19','V20','V21','V22','V23','V24','V25','V26','V27','V28','Amount']] = \
X.loc[:,['Time','V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12','V13','V14','V15','V16','V17','V18','V19','V20','V21','V22','V23','V24','V25','V26','V27','V28','Amount']].apply(enc.fit_transform)
X.head()
# Out:
#    Time      V1      V2      V3      V4  ...     V25     V26     V27     V28  Amount
# 0     0   44928  120599  270851  243083  ...  160454  105171  218749  102230   13502
# 1     0  190308  160391  134835  182525  ...  168529  179871  126158  142841     268
# 2     1   44982   28959  251918  175559  ...   68122  117706   81907   61165   23493
# 3     1   67135  107605  252751   68890  ...  253297   96705  191339  195684   11549
# 4     2   55018  212082  240745  177861  ...   94807  232984  235552  255032    6905
#
# [5 rows x 30 columns]

# %% [markdown]
# #Splitting

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = \
train_test_split(X,y,test_size=0.1,random_state=10)

# %% [markdown]
# #Implementing SMOTE

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
X_train_smote, y_train_smote = smote.fit_sample(X_train.astype('float'),y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
from collections import Counter
print("Before SMOTE :" , Counter(y_train))
print("After SMOTE :" , Counter(y_train_smote))
# Out:
# Before SMOTE : Counter({0: 255882, 1: 444})
# After SMOTE : Counter({0: 255882, 1: 255882})

# %% [markdown]
# #Post SMOTE model

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score
model.fit(X_train_smote,y_train_smote)
y_predict = model.predict(X_test)
print(accuracy_score(y_test,y_predict))
pd.crosstab(y_test,y_predict)
# Out:
# 0.9979284435237527
# col_0      0   1
# Class
# 0      28382  51
# 1          8  40

# %%
tp = 40
tn = 28382
fp = 51
fn = 8
recall = tp/(tp + fn)
print("Recall: ", recall)
prec = tp / (tp + fp)
print("Precision: ",prec)
F1 = 2 * (prec * recall) / (prec + recall)
print("F1 Score: ",F1)
# Out:
# Recall:  0.8333333333333334
# Precision:  0.43956043956043955
# F1 Score:  0.5755395683453238
